# %% [markdown]
# # idx, rec 파일을 살펴보자
# - https://github.com/deepinsight/insightface/issues/121

# %%
from mxnet import recordio
import mxnet as mx
import matplotlib.pyplot as plt
import os
import pandas as pd

# %% [markdown]
# ### my_vgg

# %%
path_imgidx = '../data/my_vgg/aligned_vgg.idx'
path_imgrec = '../data/my_vgg/aligned_vgg.rec'
print(os.path.isfile(path_imgidx))
print(os.path.isfile(path_imgrec))
# Out:
# True
# True

# %%
imgrec = recordio.MXIndexedRecordIO(path_imgidx, path_imgrec, 'r')

# %%
#%% 1 ~ 3123756
for i in range(3123753, 3123756):
    header, s = recordio.unpack(imgrec.read_idx(i+1))
    print(header)
    
    img = mx.image.imdecode(s).asnumpy() 
    plt.imshow(img)
    plt.title('id=' + str(i) + 'label=' + str(header.label))
    plt.pause(0.1)
# Out:
# HEADER(flag=2, label=array([8.63e+03, 1.00e+00], dtype=float32), id=3123754, id2=0)
# HEADER(flag=2, label=array([8.63e+03, 1.00e+00], dtype=float32), id=3123755, id2=0)
# HEADER(flag=2, label=array([8.63e+03, 1.00e+00], dtype=float32), id=3123756, id2=0)

# %% [markdown]
# ### faces_vgg2_112x112

# %%
path_imgidx = '../data/faces_vgg2_112x112/train.idx'
path_imgrec = '../data/faces_vgg2_112x112/train.rec'
print(os.path.isfile(path_imgidx))
print(os.path.isfile(path_imgrec))
# Out:
# True
# True

# %%
imgrec = recordio.MXIndexedRecordIO(path_imgidx, path_imgrec, 'r')

# %%
#%% 1 ~ 3137807
for i in range(3137804, 3137810):
    header, s = recordio.unpack(imgrec.read_idx(i+1))
    
    print(header)
    
    img = mx.image.imdecode(s).asnumpy() 
    plt.imshow(img)
    plt.title('id=' + str(i) + 'label=' + str(header.label))
    plt.pause(0.1)
# Out:
# HEADER(flag=0, label=8630.0, id=3137805, id2=0)
# HEADER(flag=0, label=8630.0, id=3137806, id2=0)
# HEADER(flag=0, label=8630.0, id=3137807, id2=0)
# HEADER(flag=2, label=array([  1., 316.], dtype=float32), id=3137808, id2=0)
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# <ipython-input-45-e602c6d28965> in <module>
#       5     print(header)
#       6
# ----> 7     img = mx.image.imdecode(s).asnumpy()
#       8     plt.imshow(img)
#       9     plt.title('id=' + str(i) + 'label=' + str(header.label))
#
# c:\users\shiney\documents\workspace\pytorch\lib\site-packages\mxnet\image\image.py in imdecode(buf, *args, **kwargs)
#     206
#     207     cvimdecode = _npi.cvimdecode if is_np_array() else _internal._cvimdecode
# --> 208     return cvimdecode(buf, *args, **kwargs)
#     209
#     210
#
# c:\users\shiney\documents\workspace\pytorch\lib\site-packages\mxnet\ndarray\register.py in _cvimdecode(buf, flag, to_rgb, out, name, **kwargs)
#
# c:\users\shiney\documents\workspace\pytorch\lib\site-packages\mxnet\_ctypes\ndarray.py in _imperative_invoke(handle, ndargs, keys, vals, out, is_np_op)
#     105         c_str_array(keys),
#     106         c_str_array([str(s) for s in vals]),
# --> 107         ctypes.byref(out_stypes)))
#     108
#     109     create_ndarray_fn = _np_ndarray_cls if is_np_op else _ndarray_cls
#
# c:\users\shiney\documents\workspace\pytorch\lib\site-packages\mxnet\base.py in check_call(ret)
#     253     """
#     254     if ret != 0:
# --> 255         raise MXNetError(py_str(_LIB.MXGetLastError()))
#     256
#     257
#
# MXNetError: [23:36:36] C:\Jenkins\workspace\mxnet-tag\mxnet\src\io\image_io.cc:190: Check failed: len > 0: Input cannot be an empty buffer
