# %%
import os
import pandas as pd

# %%
my_idx = '../data/my_vgg/aligned_vgg.idx'

# %%
 os.path.isfile(my_idx))
# Out:
# True True

# %% [markdown]
# ## small_vgg.idx

# %%
smallvgg_idx = '../data/small_vgg/small_vgg_112x112.idx'
print(os.path.isfile(smallvgg_idx))
# Out:
# True

# %%
f = open(smallvgg_idx, 'rb')

i = 0
while True:
    line = f.readline()
    print(line.decode())
    i +=1
    if i == 300:
        break
# Out:
# 1	0
#
# 2	5700
#
# 3	12648
#
# 4	19940
#
# 5	27800
#
# 6	35780
#
# 7	42628
#
# 8	49484
#
# 9	57724
#
# 10	64632
#
# 11	71528
#
# 12	77972
#
# 13	84776
#
# 14	91384
#
# 15	98660
#
# 16	105392
#
# 17	112548
#
# 18	119620
#
# 19	126036
#
# 20	134268
#
# 21	140796
#
# 22	148248
#
# 23	154468
#
# 24	160756
#
# 25	166300
#
# 26	174116
#
# 27	180460
#
# 28	187580
#
# 29	193904
#
# 30	200324
#
# 31	206548
#
# 32	213500
#
# 33	220288
#
# 34	228036
#
# 35	234932
#
# 36	241500
#
# 37	248480
#
# 38	255020
#
# 39	263212
#
# 40	269292
#
# 41	276668
#
# 42	283616
#
# 43	291236
#
# 44	298072
#
# 45	304996
#
# 46	312548
#
# 47	320500
#
# 48	327296
#
# 49	335264
#
# 50	341256
#
# 51	349260
#
# 52	355704
#
# 53	362776
#
# 54	369200
#
# 55	376480
#
# 56	382988
#
# 57	390040
#
# 58	395092
#
# 59	400952
#
# 60	409092
#
# 61	415740
#
# 62	423520
#
# 63	429512
#
# 64	436884
#
# 65	445416
#
# 66	452168
#
# 67	459328
#
# 68	464160
#
# 69	471084
#
# 70	477984
#
# 71	484096
#
# 72	491208
#
# 73	497128
#
# ...

# %% [markdown]
# ## ordinary_idx

# %%
ordinary_idx = '../data/faces_vgg2_112x112/train.idx'
print(os.path.isfile(ordinary_idx))
# Out:
# True

# %%
ordinary_data = pd.read_csv(ordinary_idx)
print(len(ordinary_data))
# Out:
# 3146438

# %%
f = open(ordinary_idx, 'rb')

i = 0
while True:
    line = f.readline()
    print(line.decode())
    i +=1
    if i == 10:
        break
# Out:
# 1	0
#
# 2	8160
#
# 3	14820
#
# 4	22156
#
# 5	29296
#
# 6	34760
#
# 7	41380
#
# 8	47148
#
# 9	52840
#
# 10	58980

# %% [markdown]
# ## my_idx

# %%
my_idx = '../data/faces_vgg2_112x112/train.idx'
print(os.path.isfile(my_idx))
# Out:
# True

# %%
my_data = pd.read_csv(my_idx)
print(len(my_data))
# Out:
# 3146438

# %%
f = open(my_idx, 'rb')

i = 0
while True:
    line = f.readline()
    print(line.decode())
    i +=1
    if i == 10:
        break
# Out:
# 1	0
#
# 2	3020
#
# 3	5596
#
# 4	8392
#
# 5	11292
#
# 6	13924
#
# 7	16408
#
# 8	18896
#
# 9	22724
#
# 10	25836
